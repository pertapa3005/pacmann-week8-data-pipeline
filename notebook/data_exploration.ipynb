# %%
pip install pandas sqlalchemy psycopg2-binary jupyter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql://postgres:postgres@localhost:5433/source_db"
)

df = pd.read_sql(
    "SELECT * FROM car_sales",
    engine
)

df.head()
# Out:
#    id_sales  year  brand_car            model      trim         body  \
# 0         1  2014  Chevrolet   Impala Limited  LT Fleet        Sedan
# 1         2  2003      Dodge  Ram Pickup 1500       SLT     Quad Cab
# 2         3  2007    Pontiac               G6        GT  Convertible
# 3         4  2011     Toyota          Corolla        LE        Sedan
# 4         5  2012      Lexus           ES 350      Base        Sedan
#
#   transmission                vin state  condition  odometer  color interior  \
# 0    automatic  2g1wb5e37e1112559    fl        4.0   21507.0  white    black
# 1               1d7ha18n13s152972    mo       31.0   79712.0      —    black
# 2    automatic  1g2zh361474252178    nj       34.0   65698.0    red    black
# 3    automatic  jtdbu4eexb9167571    fl       43.0   23634.0  black    beige
# 4               jthbk1eg6c2495519    pa       35.0   26483.0  black    brown
#
#                              seller      mmr  sellingprice  \
# ...

# %%
df.shape
# Out:
# (30000, 17)

# %%
df.isnull().sum()
# Out:
# id_sales          0
# year              0
# brand_car         0
# model             0
# trim              0
# body              0
# transmission      0
# vin               0
# state             0
# condition       659
# odometer          7
# color             0
# interior          0
# seller            0
# mmr               2
# sellingprice      0
# saledate          0
# dtype: int64

# %%
df.dtypes
# Out:
# id_sales          int64
# year              int64
# brand_car        object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
df.describe()
# Out:
#            id_sales          year     condition       odometer            mmr  \
# count  30000.000000  30000.000000  29341.000000   29993.000000   29998.000000
# mean   15000.500000   2010.042100     30.765482   68251.487547   13750.143343
# std     8660.398374      3.975616     13.417235   53430.661298    9690.636769
# min        1.000000   1985.000000      1.000000       1.000000      25.000000
# 25%     7500.750000   2007.000000     24.000000   27926.000000    7050.000000
# 50%    15000.500000   2012.000000     35.000000   51923.000000   12300.000000
# 75%    22500.250000   2013.000000     42.000000   99277.000000   18300.000000
# max    30000.000000   2015.000000     49.000000  999999.000000  146000.000000
#
#         sellingprice
# count   30000.000000
# mean    13587.186067
# std      9729.455229
# min       100.000000
# 25%      6900.000000
# 50%     12200.000000
# 75%     18200.000000
# max    154000.000000
